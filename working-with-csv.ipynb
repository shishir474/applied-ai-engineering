# %%
import pandas as pd

# %% [markdown]
# ## load file from local machine

# %%
pd.read_csv()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # load file from local machine
# ----> 2 pd.read_csv()
#
# TypeError: read_csv() missing 1 required positional argument: 'filepath_or_buffer'

# %% [markdown]
# ## load csv file from a url

# %% [markdown]
# ## Sep Parameter

# %%
# default separator is ','
# use \t while reading a tsv file

# %% [markdown]
# ## index_col parameter

# %%
# removes the default pandas index. Usefull when your dataset has a index like column and you don't need default pandas index

# %% [markdown]
# ## Header parameter

# %% [markdown]
# ## use_cols parameter

# %% [markdown]
# ## squeeze parameter

# %%
# generates pandas series instead of pandas dataframe

# %% [markdown]
# ## skiprows/nrows parameter

# %% [markdown]
# ## Encoding parameter

# %%
# default encoding is utf-8
# UnicodeDecodeError signifies that the dataset follows a different encoding scheme.
# figure out what encoding is used & use that while reading the file.

# %% [markdown]
# ## skip bad lines

# %%
# some rows might have more columns.
# for ex: error like on line 6652 expected 8 cols, saw 9 --> 
# set error_bad_lines = False --> this will skip all those bad rows

# %% [markdown]
# ## dtypes parameter

# %%
# you can change the default datatype of columns if you want to 
# usefull in saving the memory -- ex: a col saved in float contains values like 1.0, 2.0 etc -- can be saved as int.

# %% [markdown]
# ## Handling dates

# %%
# by default read_csv() treats dates columns as strings. Problem is you will not be able to apply date related functionality on them.
# parse_dates = [col1, col2]
# specify the column names that you want to parse as dates. 
# In pandas object datatype represent string

# %% [markdown]
# ## Converters

# %%
# very powerfull feature of read_csv
# we can transform column values while reading the csv
# converters={colname: functionName}

# The function will be applied on the column and the values will be transformed accordingly

# %% [markdown]
# ## na_values parameter

# %%
# using this we can specify what all values we want to treat as NaN.
#     For ex: sometime we might see - (hiphen) as values. ideally we can treat it as NaN.
# na_values = ['-'] 
# I can pass a list of values which read_csv() will treat as NaN.

# %% [markdown]
# ## Loading a huge dataset in chunks

# %%
# specify chunksize = 5000 
# loads dataset in chunks of 5000 size
# gives us a list of dataframes
# dfs = pd.read_csv('aug_train.csv', chunksize = 5000)

# # loop over 
# for chunks in dfs:
#     print(chunks.shape)

# idea is we can load the entire dataset in chunks (chunksize is configurable). You can thing that 
# these will return me a list of dataframes. Whatever operations you want to apply, you will have to loop over each dataframe and then apply the operation
